# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
import csv
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Query by text search
# Setting variables to be used in format string command below
tweet_count = 500
text_query = "Shark Tank"
since_date = "2019-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))


# Reads the json generated from the CLI command above and creates a pandas dataframe
df1 = pd.read_json('text-query-tweets.json', lines=True)

# %%
df1.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/caitlin__cara/status/13447...
# 1  https://twitter.com/TheWizardOfIce/status/1344...
# 2  https://twitter.com/Virgini43077700/status/134...
# 3  https://twitter.com/RemyLabaux/status/13447933...
# 4  https://twitter.com/ButchMoore15/status/134479...
#
#                        date  \
# 0 2020-12-31 23:58:25+00:00
# 1 2020-12-31 23:54:23+00:00
# 2 2020-12-31 23:52:30+00:00
# 3 2020-12-31 23:51:41+00:00
# 4 2020-12-31 23:49:58+00:00
#
#                                              content  \
# 0  Feb 11, 2020: hosted my first Sampling with th...
# 1  @ECochnar @AliBondGirl I agree with the first ...
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...
# 4  @mcuban Mark your the biggest hypocrite on the...
#
#                                      renderedContent                   id  \
# 0  Feb 11, 2020: hosted my first Sampling with th...  1344795076124262400
# 1  @ECochnar @AliBondGirl I agree with the first ...  1344794058535923713
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....  1344793584738959360
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...  1344793381503967233
# 4  @mcuban Mark your the biggest hypocrite on the...  1344792946932133888
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           4
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  retweetedTweet  \
# 0             0         20  ...             NaN
# 1             0          3  ...             NaN
# 2             0          0  ...             NaN
# 3             0          0  ...             NaN
# 4             1          1  ...             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 0  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 1                                               None     1.344764e+18
# 2                                               None     1.344759e+18
# 3                                               None     1.344785e+18
# 4                                               None     1.344753e+18
#
#                                        inReplyToUser  \
# 0                                               None
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers  \
# 0                                               None
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                          coordinates  \
# 0  {'_type': 'snscrape.modules.twitter.Coordinate...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                place hashtags cashtags  card
# 0  {'_type': 'snscrape.modules.twitter.Place', 'f...     None     None  None
# 1                                               None     None     None  None
# 2                                               None     None     None  None
# 3                                               None     None     None  None
# 4                                               None     None     None  None
#
# [5 rows x 29 columns]

# %%
tweet_count = 500
text_query = "shark tank Memes"
#since_date = "2019-01-01"
#until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))


# Reads the json generated from the CLI command above and creates a pandas dataframe
df2 = pd.read_json('text-query-tweets.json', lines=True)

# %%
df2.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/fremadethis/status/1343903...
# 1  https://twitter.com/Kiri1898/status/1342363925...
# 2  https://twitter.com/roleodelavword/status/1342...
# 3  https://twitter.com/baconranchwrap/status/1340...
# 4  https://twitter.com/Pollisaurio/status/1338940...
#
#                        date  \
# 0 2020-12-29 12:56:16+00:00
# 1 2020-12-25 06:57:54+00:00
# 2 2020-12-24 17:50:18+00:00
# 3 2020-12-20 19:56:50+00:00
# 4 2020-12-15 20:14:41+00:00
#
#                                              content  \
# 0  Kevin : I'm Kevin\nRobert : I'm Robert.\nLori ...
# 1  Toca su capitulito de shark tank pa ir bien a ...
# 2  @xcupofme Tengo muchos memes de shark tank jaj...
# 3          Huge fan of the shark tank cock meme meta
# 4  Mi jefa dijo "Sharknado" en lugar de "Shark Ta...
#
#                                      renderedContent                   id  \
# 0  Kevin : I'm Kevin\nRobert : I'm Robert.\nLori ...  1343903663882870784
# 1  Toca su capitulito de shark tank pa ir bien a ...  1342363925711626240
# 2  @xcupofme Tengo muchos memes de shark tank jaj...  1342165721535684609
# 3          Huge fan of the shark tank cock meme meta  1340748012340047872
# 4  Mi jefa dijo "Sharknado" en lugar de "Shark Ta...  1338940563425550337
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  retweetedTweet  quotedTweet inReplyToTweetId  \
# 0             0          0  ...             NaN         None              NaN
# 1             0          1  ...             NaN         None              NaN
# 2             0          0  ...             NaN         None              NaN
# 3             0          2  ...             NaN         None              NaN
# 4             0          9  ...             NaN         None              NaN
#
#   inReplyToUser mentionedUsers coordinates place hashtags cashtags  card
# 0          None           None        None  None     None      NaN  None
# 1          None           None        None  None     None      NaN  None
# 2          None           None        None  None     None      NaN  None
# 3          None           None        None  None     None      NaN  None
# 4          None           None        None  None     None      NaN  None
#
# [5 rows x 29 columns]

# %%
frames = [df1, df2]

# %%
result = pd.concat(frames)

# %%
df=pd.DataFrame(result)

# %%
df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/caitlin__cara/status/13447...
# 1  https://twitter.com/TheWizardOfIce/status/1344...
# 2  https://twitter.com/Virgini43077700/status/134...
# 3  https://twitter.com/RemyLabaux/status/13447933...
# 4  https://twitter.com/ButchMoore15/status/134479...
#
#                        date  \
# 0 2020-12-31 23:58:25+00:00
# 1 2020-12-31 23:54:23+00:00
# 2 2020-12-31 23:52:30+00:00
# 3 2020-12-31 23:51:41+00:00
# 4 2020-12-31 23:49:58+00:00
#
#                                              content  \
# 0  Feb 11, 2020: hosted my first Sampling with th...
# 1  @ECochnar @AliBondGirl I agree with the first ...
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...
# 4  @mcuban Mark your the biggest hypocrite on the...
#
#                                      renderedContent                   id  \
# 0  Feb 11, 2020: hosted my first Sampling with th...  1344795076124262400
# 1  @ECochnar @AliBondGirl I agree with the first ...  1344794058535923713
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....  1344793584738959360
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...  1344793381503967233
# 4  @mcuban Mark your the biggest hypocrite on the...  1344792946932133888
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           4
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  retweetedTweet  \
# 0             0         20  ...             NaN
# 1             0          3  ...             NaN
# 2             0          0  ...             NaN
# 3             0          0  ...             NaN
# 4             1          1  ...             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 0  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 1                                               None     1.344764e+18
# 2                                               None     1.344759e+18
# 3                                               None     1.344785e+18
# 4                                               None     1.344753e+18
#
#                                        inReplyToUser  \
# 0                                               None
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers  \
# 0                                               None
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                          coordinates  \
# 0  {'_type': 'snscrape.modules.twitter.Coordinate...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                place hashtags cashtags  card
# 0  {'_type': 'snscrape.modules.twitter.Place', 'f...     None     None  None
# 1                                               None     None     None  None
# 2                                               None     None     None  None
# 3                                               None     None     None  None
# 4                                               None     None     None  None
#
# [5 rows x 29 columns]

# %%
def cleanText(text):
    text = re.sub(r'@[A-Za-z0-9]+','',text) # Removed @mentions
    text = re.sub(r'#','',text) #Removing the # symbols
    text = re.sub(r':','',text) #Removing the : symbols
    text = re.sub(r'_','',text) #Removing the : symbols
    text = re.sub(r'RT[\s]+','',text) #Removing RT
    text = re.sub(r'https?:\/\/\S+','', text) # Removing the hyper link
    return text
df['content']=df['content'].apply(cleanText)

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['Subjectivity'] = df['content'].apply(getSubjectivity)
df['Polarity'] = df['content'].apply(getPolarity)

df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/caitlin__cara/status/13447...
# 1  https://twitter.com/TheWizardOfIce/status/1344...
# 2  https://twitter.com/Virgini43077700/status/134...
# 3  https://twitter.com/RemyLabaux/status/13447933...
# 4  https://twitter.com/ButchMoore15/status/134479...
#
#                        date  \
# 0 2020-12-31 23:58:25+00:00
# 1 2020-12-31 23:54:23+00:00
# 2 2020-12-31 23:52:30+00:00
# 3 2020-12-31 23:51:41+00:00
# 4 2020-12-31 23:49:58+00:00
#
#                                              content  \
# 0  Feb 11, 2020 hosted my first Sampling with the...
# 1    I agree with the first part of your statemen...
# 2      Love it. Great idea. Is that a Shark Tank ...
# 3      I read alot of books, got the shark tank l...
# 4   Mark your the biggest hypocrite on the plant,...
#
#                                      renderedContent                   id  \
# 0  Feb 11, 2020: hosted my first Sampling with th...  1344795076124262400
# 1  @ECochnar @AliBondGirl I agree with the first ...  1344794058535923713
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....  1344793584738959360
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...  1344793381503967233
# 4  @mcuban Mark your the biggest hypocrite on the...  1344792946932133888
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           4
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  inReplyToTweetId  \
# 0             0         20  ...               NaN
# 1             0          3  ...      1.344764e+18
# 2             0          0  ...      1.344759e+18
# 3             0          0  ...      1.344785e+18
# 4             1          1  ...      1.344753e+18
#
#                                        inReplyToUser  \
# 0                                               None
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers  \
# 0                                               None
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                          coordinates  \
# 0  {'_type': 'snscrape.modules.twitter.Coordinate...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                place hashtags cashtags  card  \
# 0  {'_type': 'snscrape.modules.twitter.Place', 'f...     None     None  None
# 1                                               None     None     None  None
# 2                                               None     None     None  None
# 3                                               None     None     None  None
# 4                                               None     None     None  None
#
#   Subjectivity  Polarity
# 0     0.444444  0.416667
# 1     0.681313 -0.132828
# 2     0.675000  0.650000
# 3     0.750000  0.693750
# 4     0.580000  0.412187
#
# [5 rows x 31 columns]

# %%
df.to_csv('~/Desktop/finaldata1.csv')

# %%
allWords=' '.join([twts for twts in df['content']])
wordCloud=WordCloud(width=500,height=300,random_state=21,max_font_size=119).generate(allWords)
plt.imshow(wordCloud,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# Create a function to compute the negative, neutral and positive analysis
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
df['Analysis'] = df['Polarity'].apply(getAnalysis)

df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/caitlin__cara/status/13447...
# 1  https://twitter.com/TheWizardOfIce/status/1344...
# 2  https://twitter.com/Virgini43077700/status/134...
# 3  https://twitter.com/RemyLabaux/status/13447933...
# 4  https://twitter.com/ButchMoore15/status/134479...
#
#                        date  \
# 0 2020-12-31 23:58:25+00:00
# 1 2020-12-31 23:54:23+00:00
# 2 2020-12-31 23:52:30+00:00
# 3 2020-12-31 23:51:41+00:00
# 4 2020-12-31 23:49:58+00:00
#
#                                              content  \
# 0  Feb 11, 2020 hosted my first Sampling with the...
# 1    I agree with the first part of your statemen...
# 2      Love it. Great idea. Is that a Shark Tank ...
# 3      I read alot of books, got the shark tank l...
# 4   Mark your the biggest hypocrite on the plant,...
#
#                                      renderedContent                   id  \
# 0  Feb 11, 2020: hosted my first Sampling with th...  1344795076124262400
# 1  @ECochnar @AliBondGirl I agree with the first ...  1344794058535923713
# 2  @misspell @Cecilyjk @msdeb903 @yashar Love it....  1344793584738959360
# 3  @Dracalous @aghenis @AlpKelvyn @ksorbs I read ...  1344793381503967233
# 4  @mcuban Mark your the biggest hypocrite on the...  1344792946932133888
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           4
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  \
# 0             0         20  ...
# 1             0          3  ...
# 2             0          0  ...
# 3             0          0  ...
# 4             1          1  ...
#
#                                        inReplyToUser  \
# 0                                               None
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers  \
# 0                                               None
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                          coordinates  \
# 0  {'_type': 'snscrape.modules.twitter.Coordinate...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                place hashtags cashtags  card  \
# 0  {'_type': 'snscrape.modules.twitter.Place', 'f...     None     None  None
# 1                                               None     None     None  None
# 2                                               None     None     None  None
# 3                                               None     None     None  None
# 4                                               None     None     None  None
#
#   Subjectivity  Polarity  Analysis
# 0     0.444444  0.416667  Positive
# 1     0.681313 -0.132828  Negative
# 2     0.675000  0.650000  Positive
# 3     0.750000  0.693750  Positive
# 4     0.580000  0.412187  Positive
#
# [5 rows x 32 columns]

# %%
# Show the value counts
df['Analysis'].value_counts()

#plot and visualize the counts
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
result['Analysis'].value_counts().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
